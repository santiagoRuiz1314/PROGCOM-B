# %% [markdown]
# Test1

# %% [markdown]
# ![photo_4940778554975694624_y.jpg](data:image/jpeg;base64,...)![photo_4940778554975694623_y.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# 1.4. Reto 1. ¡Hola mundo!

# %% [markdown]
# ![photo_4940514728019603442_y.jpg](data:image/jpeg;base64,...)![photo_4940514728019603443_y.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# 1.5. Reto 2. Imágenes

# %% [markdown]
# ![photo_4940514728019603447_y.jpg](data:image/jpeg;base64,...)![photo_4940514728019603446_y.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# 1.6. Reto 3. Botones

# %% [markdown]
# ![photo_4940514728019603448_y.jpg](data:image/jpeg;base64,...)![photo_4940514728019603449_y.jpg](data:image/jpeg;base64,...)
